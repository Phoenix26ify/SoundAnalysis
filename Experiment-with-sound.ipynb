# %%
# This part of the code includes importing the libraries and loading the audio file

import time
import numpy as np
import matplotlib.pyplot as plt
import librosa
data, sr = librosa.load('/Users/shreyamitra/Downloads/Adele-Skyfall-iTunes-128.mp3')
# Out:
# /Users/shreyamitra/opt/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')

# %%
print(data.shape)
# Out:
# (6312384,)

# %%
print(sr)
# Out:
# 22050

# %%
plt.plot(data)

# %%
plt.show()

# %%
start=time.clock()
# Out:
# /Users/shreyamitra/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
#   """Entry point for launching an IPython kernel.

# %%
test_array_default, _ = librosa.load('/Users/shreyamitra/Downloads/Adele-Skyfall-iTunes-128.mp3')
# Out:
# /Users/shreyamitra/opt/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')

# %%
print(time.clock()-start)
# Out:
# 14.621682000000021
# /Users/shreyamitra/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
#   """Entry point for launching an IPython kernel.

# %%
# New Sample Rate
start = time.clock()

test_array_default, _ = librosa.load('/Users/shreyamitra/Downloads/Adele-Skyfall-iTunes-128.mp3', sr=11000)

print(time.clock()-start)
# Out:
# /Users/shreyamitra/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
#
# /Users/shreyamitra/opt/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# 12.014099999999985
# /Users/shreyamitra/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead

# %%
start = time.clock()
test_array_default, _ = librosa.load('/Users/shreyamitra/Downloads/Adele-Skyfall-iTunes-128.mp3', res_type='kaiser_fast')
print(time.clock()-start)
# Out:
# /Users/shreyamitra/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
#   """Entry point for launching an IPython kernel.
# /Users/shreyamitra/opt/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# 4.06523900000002
# /Users/shreyamitra/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
spec = librosa.feature.melspectrogram(y=data, sr=sr)
import librosa.display
librosa.display.specshow(spec,y_axis='mel', x_axis='s', sr=sr)
plt.colorbar()

# %%
db_spec = librosa.power_to_db(spec, ref=np.max,)
librosa.display.specshow(db_spec,y_axis='mel', x_axis='s', sr=sr)
plt.colorbar();

# %%
data_h, data_p = librosa.effects.hpss(data)
spec_h = librosa.feature.melspectrogram(data_h, sr=sr)
spec_p = librosa.feature.melspectrogram(data_p, sr=sr)
db_spec_h = librosa.power_to_db(spec_h,ref=np.max)
db_spec_p = librosa.power_to_db(spec_p,ref=np.max)

# %%
chroma = librosa.feature.chroma_cqt(y=data_h, sr=sr)
plt.figure(figsize=(18,5))
librosa.display.specshow(chroma, sr=sr, x_axis='time', y_axis='chroma', vmin=0, vmax=1)
plt.title('Chromagram')
plt.colorbar()
plt.figure(figsize=(20,8))
plt.title('Skyfall Adelle : Chroma Spectrogram')
librosa.display.specshow(chroma, sr=sr, x_axis='s', y_axis='chroma', );

# %%
print(librosa.beat.tempo(data, sr=sr))
# Out:
# [143.5546875]
